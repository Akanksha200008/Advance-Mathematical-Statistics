# %% [markdown]
# <a href="https://colab.research.google.com/github/Akanksha200008/Advance-Mathematical-Statistics/blob/main/Project_1b_Crab_Molt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data= pd.read_csv("https://raw.githubusercontent.com/Akanksha200008/Advance-Mathematical-Statistics/refs/heads/main/Crab_Molt.csv")
data.head(10)
# Out:
#    post molt size  pre molt size
# 0           127.7          113.6
# 1           133.2          118.1
# 2           135.3          119.9
# 3           143.3          126.2
# 4           139.3          126.7
# 5           140.2          127.3
# 6           143.8          128.2
# 7           144.6          129.5
# 8           147.6          130.5
# 9           144.8          131.6

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Setting up the plotting parameters
plt.figure(figsize=(9, 7))
sns.set(style="whitegrid")

# Creating a smooth histogram using seaborn
sns.histplot(data['post molt size'], kde=True, color='red', bins=20, edgecolor='Black')

# Set plot labels and title
plt.xlabel('Post Molt Size',fontsize=12,fontweight='bold')
plt.ylabel('Frequency',fontsize=12,fontweight='bold')
plt.title('Smooth Histogram of Post Molt Size',fontsize=12,fontweight='bold')

# Add a grid for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Use tight layout to avoid cutting off parts of the graph
plt.tight_layout()
# Show the plot
plt.show()

# %%
# Extracting the 'post_molt_size' column
post_molt_size_data = data['post molt size']

# Calculating statistics
max_value = post_molt_size_data.max ()
min_value = post_molt_size_data.min()

mean_value = post_molt_size_data.mean()
median_value = post_molt_size_data.median()

skewness_value = post_molt_size_data. skew()
kurtosis_value = post_molt_size_data. kurtosis()

# Displaying the results
print(f'Maximum value of post molt size: {max_value}')
print (f'Minimum value of post molt size: {min_value}')
print(f'Mean value of post molt size: {mean_value}')
print (f'Median value of post molt size: {median_value}')
print(f'Skewness: {skewness_value}')
print(f'Kurtosis: {kurtosis_value}')
# Out:
# Maximum value of post molt size: 166.8
# Minimum value of post molt size: 38.8
# Mean value of post molt size: 143.89766949152542
# Median value of post molt size: 147.4
# Skewness: -2.354390947858422
# Kurtosis: 10.23684737910977

# %%
import scipy.stats as stats

column_data = data['post molt size']

fig, ax = plt.subplots(figsize=(9, 6))

#create a quantile plot
stats.probplot(column_data, dist="norm", plot=plt)

lines = ax.get_lines()
if len(lines) > 1:
    lines[0].set_marker('o')
    lines[0].set_markerfacecolor('Blue')
    lines[0].set_markeredgecolor('Teal')
    lines[0].set_alpha(0.8)

plt.title('Qunatile plot of Post Molt Size ', fontsize=12,fontweight='bold')
plt.xlabel('Theoretical Quantiles',fontsize=12,fontweight='bold')
plt.ylabel('Sample Quantiles',fontsize=12,fontweight='bold')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Setting up the plotting parameters
plt.figure(figsize=(9, 7))
sns.set(style="whitegrid")

# Creating a smooth histogram using seaborn
sns.histplot(data['pre molt size'], kde=True, color='green', bins=20, edgecolor='Black')

# Set plot labels and title
plt.xlabel('Pre Molt Size',fontsize=12,fontweight='bold')
plt.ylabel('Frequency',fontsize=12,fontweight='bold')
plt.title('Smooth Histogram of Pre Molt Size',fontsize=12,fontweight='bold')

# Add a grid for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Use tight layout to avoid cutting off parts of the graph
plt.tight_layout()
# Show the plot
plt.show()

# %%
#extracting pre-molt size data
pre_molt_data = data['pre molt size']

# Calculating statistics
max_value = pre_molt_data.max()
min_value = pre_molt_data.min()

mean_value = pre_molt_data.mean()
median_value = pre_molt_data.median()


skewness_value = pre_molt_data.skew()
kurtosis_value = pre_molt_data.kurtosis()

# Displaying the results
print(f'Maximum value of pre molt size: {max_value}')
print(f'Minimum value of pre molt size: {max_value}')

print(f'Mean of pre molt size: {mean_value}')
print(f'Median of pre molt size: {median_value}')

print(f'Skewness: {skewness_value}')
print(f'Kurtosis: {kurtosis_value}')
# Out:
# Maximum value of pre molt size: 155.1
# Minimum value of pre molt size: 155.1
# Mean of pre molt size: 129.21186440677965
# Median of pre molt size: 132.8
# Skewness: -2.0098801542639126
# Kurtosis: 6.851369760728378

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# Extracting the 'pre molt size' column
pre_molt_size_data = data['pre molt size']

fig, ax = plt.subplots(figsize=(9, 6))
lines = ax.get_lines()
if len(lines) > 1:
    lines[0].set_marker('o')
    lines[0].set_markerfacecolor('Blue')
    lines[0].set_markeredgecolor('Teal')
    lines[0].set_alpha(0.8)
# Creating a quantile plot using probplot from scipy.stats
(stats.probplot(pre_molt_size_data, dist="norm", plot=plt))

# Set plot labels and title
plt.xlabel('Theoretical Quantiles',fontsize=12,fontweight='bold')
plt.ylabel('Sample Quantiles',fontsize=12,fontweight='bold')
plt.title('Quantile Plot for Pre Molt Size',fontsize=12,fontweight='bold')

# Show the plot
plt.show()

# %%
#figure size
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")

# Creating kernel density plots for post-molt size and pre-molt size data
sns.kdeplot(data['pre molt size'], label='Pre Molt Size', color='green', fill=True)
sns.kdeplot(data['post molt size'], label='Post Molt Size', color='purple', fill=True)


# Set plot labels and title
plt.xlabel('Size',fontsize=12,fontweight='bold')
plt.ylabel('Density',fontsize=12,fontweight='bold')
plt.title('Comparison of Post Molt Size and Pre Molt Size data',fontsize=12,fontweight='bold')

# Show the plot
plt.legend()
plt.show()

# %%
# Set up the plotting parameters
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the plotting parameters
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")

# Function to calculate cumulative distribution
def cumulative_distribution(data, col):
    sorted_data = np.sort(data[col])
    cumulative_prob = np.arange(1, len(sorted_data) + 1) / len(sorted_data)
    return sorted_data, cumulative_prob

# Calculate cumulative distributions for post-molt and pre-molt sizes
post_molt_size, post_molt_cdf = cumulative_distribution(data, 'post molt size')
pre_molt_size, pre_molt_cdf = cumulative_distribution(data, 'pre molt size')

# Set up the plotting parameters
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")

# Plotting cumulative distributions
plt.plot(post_molt_size, post_molt_cdf, label='Post Molt Size', color='purple')
plt.plot(pre_molt_size, pre_molt_cdf, label='Pre Molt Size', color='green')

# Set plot labels and title
plt.xlabel('Size', fontsize=12, fontweight='bold')
plt.ylabel('Cumulative Probability', fontsize=12, fontweight='bold')
plt.title('Comparison of Cumulative Distributions of Post Molt Size and Pre Molt Size', fontsize=12, fontweight='bold')

# Show the plot
plt.legend()
plt.show()

# %%
import numpy as np
from scipy.stats import ttest_ind

# Extracting post-molt size and pre-molt size data
post_molt_data = data['post molt size']
pre_molt_data = data['pre molt size']

# Calculating Cohen's d in a simple line
mean_diff = np.mean(post_molt_data) - np.mean(pre_molt_data)
pooled_std = np.sqrt((np.std(post_molt_data, ddof=1)**2 + np.std(pre_molt_data, ddof=1)**2) / 2)
cohens_d = mean_diff / pooled_std

# Print Cohen's d
print(f"Cohen's d: {cohens_d}")
# Out:
# Cohen's d: 0.9620678692342477

# %%
import numpy as np
from scipy.stats import ttest_ind

def perform_ttest(data, pre_molt_col, post_molt_col, alpha=0.05):
    # Extracting pre-molt size and post-molt size data
    pre_molt_data = data[pre_molt_col]
    post_molt_data = data[post_molt_col]

    # Perform t-test
    t_statistic, p_value = ttest_ind(pre_molt_data, post_molt_data, equal_var=False)

    # Displaying the results
    print(f"T-Statistic: {t_statistic}")
    print(f"P-Value: {p_value}")

    # Check for statistical significance
    if p_value < alpha:
        print("The mean difference is statistically significant.")
    else:
        print("The mean difference is not statistically significant.")

# Example call to the function
perform_ttest(data, 'pre molt size', 'post molt size')
# Out:
# T-Statistic: -14.779567045859308
# P-Value: 1.392686580034457e-44
# The mean difference is statistically significant.

# %%
import numpy as np

# Calculate the observed difference in means
observed_diff = np.mean(post_molt_data) - np.mean(pre_molt_data)
n_permutations = 1000

# Initialize an array to store permutation statistics
perm_statistics = np.zeros(n_permutations)

# Lengths of the pre and post molt data
n_pre_molt = len(pre_molt_data)
n_post_molt = len(post_molt_data)

# Permutation test loop
for k in range(n_permutations):
    # Combine and shuffle the data
    combined_data = np.concatenate((pre_molt_data, post_molt_data))
    np.random.shuffle(combined_data)
    # Randomly split shuffled data into two groups
    group_1_indices = np.random.choice(len(combined_data), size=n_pre_molt, replace=False)
    group_2_indices = np.setdiff1d(np.arange(len(combined_data)), group_1_indices)

    group_1 = combined_data[group_1_indices]
    group_2 = combined_data[group_2_indices]

    # Calculate the difference in means for the randomly split groups
    perm_statistics[k] = np.mean(group_1) - np.mean(group_2)

# Calculate the p-value
new_p_value = (np.abs(perm_statistics) >= np.abs(observed_diff)).mean()

# Print the observed difference and the p-value
print(f"Observed Difference: {observed_diff}")
print(f"P-value: {new_p_value}")
# Out:
# Observed Difference: 14.685805084745766
# P-value: 0.0
